# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # loading the dataset

# %%
df =pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# # checking the total duplicated values in a data.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # finding the missing values.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # filling the null values of a data.

# %%
df.director=df.director.fillna(value='undetermined')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.cast=df.cast.fillna(value='unspecified')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.country=df.country.fillna(value='unknown')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.date_added=df.date_added.fillna(value='unrevealed')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.rating=df.rating.fillna(value='not disclosed')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.duration=df.duration.fillna(value='uncertain')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # DISTRIBUTION OF CONTENT OVER DIFFERENT GENRES

# %%
df.listed_in.value_counts()
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
genre_column='listed_in'

# %%
df_genres = df[genre_column].str.split(',', expand=True).stack()
df_genres = df_genres.reset_index(level=0, drop=True)
df_genres = df_genres.to_frame(name='genre')

# %%
df_genres.value_counts()
# Out:
# genre
#  International Movies        2624
# Dramas                       1600
# Comedies                     1210
# Action & Adventure            859
# Documentaries                 829
#                              ...
# Romantic Movies                 3
# Spanish-Language TV Shows       2
# TV Sci-Fi & Fantasy             1
# LGBTQ Movies                    1
# Sports Movies                   1
# Name: count, Length: 73, dtype: int64

# %%
genre_counts = df_genres['genre'].value_counts()

# %%
top_10_counts=genre_counts.head(10)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_counts.index, y=top_10_counts.values, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Distribution of Content Over Different Genres')
plt.show()

# %% [markdown]
# # NUMBER OF TITLES RELEASED BY YEARS

# %%
df.release_year.value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
df['release_year']=pd.to_numeric(df['release_year'],errors='coerce')

# %%
df = df.dropna(subset=['release_year'])

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water     undetermined
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans     undetermined
# 4         s5  TV Show           Kota Factory     undetermined
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb     undetermined
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                           unspecified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
yearly_counts=df['release_year'].value_counts().sort_index(ascending=False)

# %%
top_10_years=yearly_counts.head(10)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=top_10_years.index,y=top_10_years.values,palette='viridis')
plt.xlabel('Release year')
plt.ylabel('number of titles')
plt.title('number of titles released by years')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # TOP 10 COUNTRIES BY NUMBER OF MOVIES

# %%
top_countries= df['country'].value_counts().head(10)

# %%
df.country.value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# unknown                                    831
# United Kingdom                             419
# Japan                                      245
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 749, dtype: int64

# %%
plt.figure(figsize=(10, 8))

# %%
top_countries.plot(kind='pie', autopct='%1.1f%%', cmap='viridis', legend=True)

plt.title('Top 10 Countries by Number of movies')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Analyze the distribution of content ratings.

# %%
rating_counts = df['rating'].value_counts()

# %%
print(df['rating'].isnull().sum())
# Out:
# 0

# %%
# Count occurrences of each rating
df['rating'].value_counts()
# Out:
# rating
# TV-MA            3207
# TV-14            2160
# TV-PG             863
# R                 799
# PG-13             490
# TV-Y7             334
# TV-Y              307
# PG                287
# TV-G              220
# NR                 80
# G                  41
# TV-Y7-FV            6
# not disclosed       4
# NC-17               3
# UR                  3
# 74 min              1
# 84 min              1
# 66 min              1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))

# %%
# Create a bar plot of the rating distribution
sns.barplot(x=rating_counts.index, y=rating_counts.values, palette='viridis')

plt.xlabel('Rating')
plt.ylabel('Number of Titles')
plt.title('Distribution of Content Ratings')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Explore the length of movies or episodes and identify any trends.

# %%
# Assuming 'duration' is the column with the length of movies/episodes
# Convert 'duration' to numeric values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['duration'] = df['duration'].str.extract('(\d+)').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   float64
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df['duration'].describe()
# Out:
# count    8804.000000
# mean       69.846888
# std        50.814828
# min         1.000000
# 25%         2.000000
# 50%        88.000000
# 75%       106.000000
# max       312.000000
# Name: duration, dtype: float64

# %%
plt.figure(figsize=(12, 6))

# %%
# Create a histogram of the durations
sns.histplot(df['duration'], bins=30, color='g', edgecolor='black')

plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Titles')
plt.title('Distribution of Movie/Episode Durations')
plt.show()

# %% [markdown]
# # Analyze Trends Over Time

# %%
#Ensure 'release_year' is in numeric format
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# %%
# Drop rows with missing release_year
df = df.dropna(subset=['release_year'])

# %%
#Group by release year and calculate the average duration
yearly_avg_duration = df.groupby('release_year')['duration'].mean()

# %%
#Plot the trends over time
plt.figure(figsize=(12, 6))

plt.plot(yearly_avg_duration.index, yearly_avg_duration.values, marker='o', linestyle='-', color='r')

plt.xlabel('Release Year')
plt.ylabel('Average Duration (minutes)')
plt.title('Average Movie/Episode Duration Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# # Analyze by Genre or Content Type

# %%
plt.figure(figsize=(12, 8))

# Create a box plot of durations by type
sns.boxplot(x='type', y='duration', data=df, palette='viridis')

plt.xlabel('Content Type')
plt.ylabel('Duration (minutes)')
plt.title('Duration Distribution by Content Type')
plt.show()

# %% [markdown]
# # Further explore the distribution of content across different countries and regions.

# %%
countries_exploded = df['country'].str.split(',').explode().str.strip()

# %%
country_counts = countries_exploded.value_counts()
print(country_counts.head(10))
# Out:
# country
# United States     3690
# India             1046
# unknown            831
# United Kingdom     806
# Canada             445
# France             393
# Japan              318
# Spain              232
# South Korea        231
# Germany            226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
country_counts.head(10).plot(kind='bar', color='seagreen')
plt.title('Top 10 Countries by Number of Titles on Netflix')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Evaluate the diversity of content by analyzing the number of unique genres and categories.

# %%
genre_counts = genres_exploded.value_counts()

# %%
print("Top 10 Genres/Categories by Frequency:")
print(genre_counts.head(10))
# Out:
# Top 10 Genres/Categories by Frequency:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
genre_counts.head(10).plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proportion of Top 10 Genres/Categories')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Investigate whether certain genres or types of content are more popular among users.

# %%
genres_exploded = df['listed_in'].str.split(',').explode().str.strip()
genre_counts = genres_exploded.value_counts()

# %%
print("Top 10 Genres by Number of Titles:")
print(genre_counts.head(10))
# Out:
# Top 10 Genres by Number of Titles:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
genre_counts.head(10).plot(kind='bar', color='purple')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Content Evolution Over Time

# %%
content_by_year = df['release_year'].value_counts().sort_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(content_by_year.index, content_by_year.values, marker='o', color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.title('Evolution of Netflix Content Over Time')
plt.grid()
plt.show()
